# %%
import torch

torch.cuda.empty_cache()

# %%
from models.model_subject import ModelSubject_Llama2

model = ModelSubject_Llama2('meta-llama/Llama-2-7b-chat-hf', 10)

container = model.inference('I am happy, how are you, my friend, 12 years old, 5 feet tall, 120 pounds, 3.5 GPA, 3 siblings, 2 parents, 1 dog, 2 cats, 1 fish, 1 hamster, 1 rabbit, 1 turtle, 1 parrot, 1 snake, 1 lizard, 1 frog, 1 spider, 1 scorpion, 1 centipede, 1 millipede, 1 cockroach, 1 ant, 1 bee, 1 wasp, 1 mosquito, 1 fly, 1 moth, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm, 1 caterpillar, 1 butterfly, 1 dragonfly, 1 grasshopper, 1 cricket, 1 beetle, 1 ladybug, 1 snail, 1 slug, 1 worm')

container
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 3
#       1 from models.model_subject import ModelSubject_Llama2
# ----> 3 model = ModelSubject_Llama2('meta-llama/Llama-2-7b-chat-hf', 10)
# ...
